# %%
import pandas as pd 
import os

# %%
id = "0"
data = pd.read_csv("./data/PropertyInfo.csv", index_col="id")


file_paths = []
for root, _, files in os.walk(f"static/images/{id}"):
    for file in files:
        if file != ".DS_Store":
            file_path = os.path.join(root, file)
            file_paths.append(file_path)
file_paths
# Out:
# ['static/images/0/pano.jpeg',
#  'static/images/0/4.JPG',
#  'static/images/0/2.JPG',
#  'static/images/0/3.JPG',
#  'static/images/0/1.JPG']

# %%
args = {
        "img": 123,
        "num_geometries":2
    }
args["img"]
# Out:
# 123

# %%
pip install pyntcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.3/346.3 kB 393.9 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from pyntcloud import PyntCloud

# human_face = PyntCloud.from_file("static/models/output/audi1_geometry_0.ply")

# human_face.plot()

# %%
pip install pygame PyOpenGL
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 61.5 kB/s eta 0:00:0000:0100:02m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame
from pygame.locals import *

from OpenGL.GL import *
from OpenGL.GLUT import *
from OpenGL.GLU import *
import pywavefront

# Initialize Pygame
pygame.init()
display = (800, 600)
pygame.display.set_mode(display, DOUBLEBUF | OPENGL)

# Set up OpenGL
gluPerspective(45, (display[0] / display[1]), 0.1, 50.0)
glTranslatef(0.0, 0.0, -5)

# Load the .obj file
model = pywavefront.Wavefront('model.obj')

def draw_model(model):
    # Set up OpenGL for drawing the model
    glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
    glLoadIdentity()

    # Draw the model
    model.draw()

    pygame.display.flip()
    pygame.time.wait(10)

def main():
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()

        draw_model(model)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 42
#      39         draw_model(model)
#      41 if __name__ == "__main__":
# ---> 42     main()
#
# Cell In[2], line 39, in main()
#      36         pygame.quit()
#      37         quit()
# ---> 39 draw_model(model)
#
# Cell In[2], line 27, in draw_model(model)
#      24 glLoadIdentity()
#      26 # Draw the model
# ---> 27 model.draw()
#      29 pygame.display.flip()
#      30 pygame.time.wait(10)
#
# AttributeError: 'Wavefront' object has no attribute 'draw'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
